# %% [markdown]
# Assignment 4.1
# Table of 7

# %%
for i in range(0,11):
  res=7*i
  print("7 X" , i , "=" , res)
# Out:
# 7 X 0 = 0
# 7 X 1 = 7
# 7 X 2 = 14
# 7 X 3 = 21
# 7 X 4 = 28
# 7 X 5 = 35
# 7 X 6 = 42
# 7 X 7 = 49
# 7 X 8 = 56
# 7 X 9 = 63
# 7 X 10 = 70

# %% [markdown]
# Table of 9

# %%
for i in range(0,11):
  res=9*i
  print("9 X" , i , "=" , res)
# Out:
# 9 X 0 = 0
# 9 X 1 = 9
# 9 X 2 = 18
# 9 X 3 = 27
# 9 X 4 = 36
# 9 X 5 = 45
# 9 X 6 = 54
# 9 X 7 = 63
# 9 X 8 = 72
# 9 X 9 = 81
# 9 X 10 = 90

# %% [markdown]
# Assignment 4.2

# %%
num = int(input("Enter the number: "))
for i in range(0, 11):
  res = num * i
  print(num , "x" , i , "=" , res)
# Out:
# Enter the number: 5
# 5 x 0 = 0
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# Assignment 4.3

# %%
num = int(input("Enter a number: "))

res = (num * (num + 1)) / 2

print("The result is:", res)
# Out:
# Enter a number: 4
# The result is: 10.0
