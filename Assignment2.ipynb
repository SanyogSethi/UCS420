# %% [markdown]
# Assignment 2.1

# %%
num1 = 13
num2 = 21
num3 = 45

res = num1 + num2 + num3
print("The result is: ", res)
# Out:
# The result is:  79

# %% [markdown]
# Assignment 2.2

# %%
str1 = "CS"
str2 = "Lab"
str3 = "Work"

finalStr = str1 + " " + str2 + " " + str3
print(finalStr)
# Out:
# CS Lab Work
